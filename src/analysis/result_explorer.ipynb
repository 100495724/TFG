# %% [markdown]
# # Act 1 — Result Explorer
#
# Notebook organizado por basket. Cada basket (A1–A15) tiene cuatro celdas:
#
# 1. Descripción del archetype
# 2. Gráficas de evolución de allocation (control / gender / geo)
# 3. Tablas de decisión (action / allocation / reasoning)
# 4. Tablas de métricas (agent gap / committee gap / dynamic summary)
#
# Para inspeccionar un basket concreto, ejecuta solo sus celdas tras la celda de **Setup**.

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline

from result_explorer import (
    load_result_csvs,
    plot_pair_all_variants,
    display_pair_tables_all_fields,
    display_pair_metrics_for_basket,
    available_pairs,
    available_seeds,
)

# ----- Configuración del análisis -----
RESULTS_PATHS = ["../results/act1_ablation_homo_llama_seed42.csv"]   # ajusta o añade más paths/globs
SEED = 42
INCLUDE_ERRORS = False

df = load_result_csvs(RESULTS_PATHS)

# Fix de variantes (alineamos variant con sensitive_attr)
df.loc[df["sensitive_attr"] == "gender",  "variant"] = "gender"
df.loc[df["sensitive_attr"] == "country", "variant"] = "geo"

print("Available pairs:", available_pairs(df))
print("Available seeds:", available_seeds(df))
# Out:
# Loaded 180 rows from 1 CSV file(s).
# Source files: ..\results\act1_ablation_homo_llama_seed42.csv
# Seeds: [42]
# pair_id count: 1
# parse_error rows: 0
# subject rows: 45
# Available pairs: ['TECH_growth']
# Available seeds: [42]

# %% [markdown]
# ## Basket A1 — HighGrowth_HighDebt
#
# **Archetype**: Alto crecimiento financiado con deuda elevada.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A1 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A1
_ = plot_pair_all_variants(
    df,
    pair_id="A1",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Plots de allocation por turno para las 3 variantes de A1
# ----> 2 _ = plot_pair_all_variants(
#       3     df,
#       4     pair_id="A1",
#       5     seed=SEED,
#       6     output_dir=None,    # None → no guarda, muestra inline
#       7     include_errors=INCLUDE_ERRORS,
#       8     show=True,
#       9 )
#
# File c:\Users\Alex\OneDrive\Documentos\GitHub\TFG\src\analysis\result_explorer.py:372, in plot_pair_all_variants(df, pair_id, seed, output_dir, include_errors, show)
#     363 def plot_pair_all_variants(
#     364     df: pd.DataFrame,
#     365     pair_id: str,
#    (...)
#     369     show: bool = True,
#     370 ) -> list[Figure]:
#     371     """Generate control, gender, and country allocation plots for one pair."""
# --> 372     resolved_pair_id = _resolve_pair_id(df, pair_id)
# ...

# %% [markdown]
# ### A1 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A1",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A1 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A1",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A2 — GoodEPS_DecliningIndustry
#
# **Archetype**: EPS sólido en industria en declive.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A2 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A2
_ = plot_pair_all_variants(
    df,
    pair_id="A2",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A2 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A2",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A2 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A2",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A3 — HighRevenue_NegativeEPS
#
# **Archetype**: Ingresos altos pero EPS negativo.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A3 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A3
_ = plot_pair_all_variants(
    df,
    pair_id="A3",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A3 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A3",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A3 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A3",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A4 — ModerateGrowth_HeavyDebt
#
# **Archetype**: Crecimiento moderado con deuda pesada.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A4 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A4
_ = plot_pair_all_variants(
    df,
    pair_id="A4",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A4 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A4",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A4 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A4",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A5 — StrongEPS_ShrinkingRevenue
#
# **Archetype**: Beneficios sólidos con ingresos cayendo.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A5 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A5
_ = plot_pair_all_variants(
    df,
    pair_id="A5",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A5 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A5",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A5 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A5",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A6 — HyperGrowth_NegativeEPS
#
# **Archetype**: Crecimiento explosivo con pérdidas.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A6 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A6
_ = plot_pair_all_variants(
    df,
    pair_id="A6",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A6 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A6",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A6 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A6",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A7 — StableMargins_CyclicalRisk
#
# **Archetype**: Márgenes estables con riesgo cíclico.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A7 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A7
_ = plot_pair_all_variants(
    df,
    pair_id="A7",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A7 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A7",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A7 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A7",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A8 — HighRevenue_ThinMargins
#
# **Archetype**: Volumen alto con márgenes finos.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A8 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A8
_ = plot_pair_all_variants(
    df,
    pair_id="A8",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A8 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A8",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A8 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A8",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A9 — DebtBurdened_Recovery
#
# **Archetype**: Deuda elevada en fase de recuperación.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A9 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A9
_ = plot_pair_all_variants(
    df,
    pair_id="A9",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A9 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A9",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A9 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A9",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A10 — SolidEPS_DisruptionRisk
#
# **Archetype**: EPS sólido bajo riesgo de disrupción.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A10 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A10
_ = plot_pair_all_variants(
    df,
    pair_id="A10",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A10 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A10",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A10 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A10",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A11 — HighRD_PreProfit
#
# **Archetype**: Inversión I+D fuerte, aún sin beneficios.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A11 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A11
_ = plot_pair_all_variants(
    df,
    pair_id="A11",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A11 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A11",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A11 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A11",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A12 — StrongCashFlow_RegulatoryRisk
#
# **Archetype**: Buen cash flow con riesgo regulatorio.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A12 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A12
_ = plot_pair_all_variants(
    df,
    pair_id="A12",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A12 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A12",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A12 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A12",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A13 — Turnaround_MixedSignals
#
# **Archetype**: Recuperación con señales mixtas.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A13 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A13
_ = plot_pair_all_variants(
    df,
    pair_id="A13",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A13 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A13",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A13 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A13",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A14 — HighGrowth_PoliticalRisk
#
# **Archetype**: Crecimiento alto con riesgo político.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A14 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A14
_ = plot_pair_all_variants(
    df,
    pair_id="A14",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A14 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A14",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A14 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A14",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ## Basket A15 — StrongLocal_LimitedGlobal
#
# **Archetype**: Fuerte local, expansión global limitada.
#
# Tres variantes: `control` (sin atributo sensible), `gender` (variación en género del CEO), `geo` (variación en origen geográfico).

# %% [markdown]
# ### A15 · Gráficas de evolución

# %%
# Plots de allocation por turno para las 3 variantes de A15
_ = plot_pair_all_variants(
    df,
    pair_id="A15",
    seed=SEED,
    output_dir=None,    # None → no guarda, muestra inline
    include_errors=INCLUDE_ERRORS,
    show=True,
)

# %% [markdown]
# ### A15 · Tablas de decisión

# %%
# Tablas pivote (turno × agente) para action / allocation / reasoning
_ = display_pair_tables_all_fields(
    df,
    pair_id="A15",
    seed=SEED,
    fields=("action", "allocation", "reasoning"),
    include_errors=INCLUDE_ERRORS,
)

# %% [markdown]
# ### A15 · Tablas de métricas

# %%
# Métricas filtradas a este basket: agent gap / committee gap / dynamic summary
_ = display_pair_metrics_for_basket(
    df,
    pair_id="A15",
    seed=SEED,
    include_errors=INCLUDE_ERRORS,
)
